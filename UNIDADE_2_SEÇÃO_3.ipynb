# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavozonato/BANCO-DE-DADOS/blob/main/UNIDADE_2_SE%C3%87%C3%83O_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML


html_code = """
<!DOCTYPE html>
<html lang="pt-br">
<head>
    <meta charset="utf-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Provedor de Internet - Projeto Integrado</title>

    <!-- CDNs recomendados nos documentos [2, 4] -->
    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.5.3/dist/css/bootstrap.min.css">
    <link rel="stylesheet" href="https://cdn.datatables.net/1.10.22/css/jquery.dataTables.min.css">

    <style>
        /* Estilos CSS baseados no arquivo estilo.css das fontes [5, 6] */
        .sobreposicao {
            min-height: 400px;
            background-color: rgba(0, 0, 0, 0.7); /* Fundo com 70% de transparência [5] */
            color: white;
            padding: 50px 0;
        }
        #quem-somos {
            background-image: url('https://images.unsplash.com/photo-1544197150-b99a580bb7a8?ixlib=rb-1.2.1&auto=format&fit=crop&w=1350&q=80');
            background-size: cover;
            background-attachment: fixed;
        }
        .card-img-top {
            font-size: 2rem;
            font-weight: bold;
        }
    </style>
</head>
<body>

    <!-- Menu Superior Responsivo [2, 7] -->
    <nav class="navbar navbar-expand-lg navbar-dark bg-dark sticky-top">
        <a class="navbar-brand" href="#">Internet Ilimitada</a>
        <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav">
            <span class="navbar-toggler-icon"></span>
        </button>
        <div class="collapse navbar-collapse" id="navbarNav">
            <ul class="navbar-nav mr-auto">
                <li class="nav-item active"><a class="nav-link" href="#">Página Inicial</a></li>
                <li class="nav-item"><a class="nav-link" href="#quem-somos">Quem somos</a></li>
                <li class="nav-item"><a class="nav-link" href="#planos">Planos</a></li>
                <li class="nav-item"><a class="nav-link" href="#contato">Contato</a></li>
            </ul>
        </div>
    </nav>

    <!-- Seção Jumbotron / Apresentação [8] -->
    <main>
        <div class="jumbotron mb-0">
            <div class="container text-center">
                <h1 class="display-4">Faça sua <strong>internet</strong> voar!</h1>
                <p class="lead">Planos combo a partir de R$ 50 sem taxa de instalação.</p>
                <a class="btn btn-info btn-lg" href="#planos" role="button">Conheça nossos planos</a>
            </div>
        </div>

        <!-- Seção Quem Somos com Overlay CSS [6, 9] -->
        <section id="quem-somos">
            <div class="sobreposicao text-center">
                <div class="container">
                    <h2 class="display-4 text-info">Quem somos?</h2>
                    <p class="lead">Atuamos há mais de 10 anos trazendo planos de internet com alta qualidade para sua família.</p>
                </div>
            </div>
        </section>

        <!-- Painel de Planos com Cards Bootstrap [10-12] -->
        <section id="planos" class="container py-5 text-center">
            <h2 class="mb-5">Nossos Planos</h2>
            <div class="row">
                <div class="col-md-3 mb-4">
                    <div class="card h-100">
                        <div class="card-header bg-light text-muted py-4"><h1>R$ 50</h1></div>
                        <div class="card-body">
                            <h5 class="card-title">Plano Alfa</h5>
                            <p class="card-text">Internet de 10 Mb com instalação grátis.</p>
                            <a href="#" class="btn btn-info">Assine já!</a>
                        </div>
                    </div>
                </div>
                <!-- Exemplo de Plano Omega (Destaque) [11] -->
                <div class="col-md-9 mb-4">
                    <div class="card h-100 border-danger text-center">
                        <div class="card-header bg-secondary text-light">CONHEÇA NOSSO PLANO EMPRESARIAL</div>
                        <div class="card-body">
                            <h5 class="card-title">Plano Ômega</h5>
                            <p class="card-text">400 Mb + TV Digital 150 canais + Suporte 24h.</p>
                            <a href="#" class="btn btn-danger">Assine já!</a>
                        </div>
                        <div class="card-footer text-muted">APENAS R$199</div>
                    </div>
                </div>
            </div>
        </section>

        <!-- Tabela Comparativa com DataTables [13-15] -->
        <section id="compare" class="bg-light py-5">
            <div class="container">
                <h2 class="text-center mb-4">Compare nossos COMBOS</h2>
                <table id="compare_planos" class="table table-striped table-hover table-responsive-sm text-center">
                    <thead>
                        <tr>
                            <th>#</th>
                            <th>Plano</th>
                            <th>Internet</th>
                            <th>Modem WiFi</th>
                            <th>Preço (R$)</th>
                        </tr>
                    </thead>
                    <tbody>
                        <tr><td>1</td><td>Alfa</td><td>10 Mb</td><td>-</td><td>50</td></tr>
                        <tr><td>2</td><td>Beta</td><td>20 Mb</td><td>Sim</td><td>90</td></tr>
                        <tr><td>3</td><td>Gama</td><td>50 Mb</td><td>Sim</td><td>120</td></tr>
                        <tr><td>4</td><td>Delta</td><td>100 Mb</td><td>Sim</td><td>150</td></tr>
                        <tr><td>5</td><td>Ômega</td><td>400 Mb</td><td>Sim</td><td>199</td></tr>
                    </tbody>
                </table>
            </div>
        </section>

        <!-- Formulário de Contato [16] -->
        <section id="contato" class="container py-5">
            <h2 class="text-center mb-4">Fale conosco</h2>
            <div class="row justify-content-center">
                <div class="col-md-8">
                    <form action="#">
                        <div class="form-group">
                            <label>Nome</label>
                            <input type="text" class="form-control" placeholder="Informe seu nome">
                        </div>
                        <div class="form-group">
                            <label>E-mail</label>
                            <input type="email" class="form-control" placeholder="Informe seu email">
                        </div>
                        <div class="form-group">
                            <label>Mensagem</label>
                            <textarea class="form-control" rows="4" placeholder="Entre com a mensagem"></textarea>
                        </div>
                        <button type="submit" class="btn btn-success btn-block">Enviar</button>
                    </form>
                </div>
            </div>
        </section>
    </main>

    <!-- Rodapé e Scripts [3, 17] -->
    <footer class="bg-dark text-light py-4 text-center">
        <p>&copy; 2021 | Projeto de Desenvolvimento Web</p>

        <!-- Scripts JQuery, Bootstrap e DataTables conforme fontes [3] -->
        <script src="https://code.jquery.com/jquery-3.5.1.min.js"></script>
        <script src="https://cdn.jsdelivr.net/npm/bootstrap@4.5.3/dist/js/bootstrap.bundle.min.js"></script>
        <script src="https://cdn.datatables.net/1.10.22/js/jquery.dataTables.min.js"></script>

        <script>
            $(document).ready(function(){
                // Inicialização do DataTables desativando busca/paginação como sugerido no PDF [3]
                $('#compare_planos').DataTable({
                    "paging":   false,
                    "searching": false,
                    "info":      false
                });
            });
        </script>
    </footer>
</body>
</html>
"""

HTML(html_code)
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
# <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Provedor de Internet - Projeto Integrado</title>
#
#     <!-- CDNs recomendados nos documentos [2, 4] -->
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.5.3/dist/css/bootstrap.min.css">
#     <link rel="stylesheet" href="https://cdn.datatables.net/1.10.22/css/jquery.dataTables.min.css">
#
#     <style>
#         /* Estilos CSS baseados no arquivo estilo.css das fontes [5, 6] */
#         .sobreposicao {
#             min-height: 400px;
#             background-color: rgba(0, 0, 0, 0.7); /* Fundo com 70% de transparência [5] */
#             color: white;
#             padding: 50px 0;
#         }
#         #quem-somos {
#             background-image: url('https://images.unsplash.com/photo-1544197150-b99a580bb7a8?ixlib=rb-1.2.1&auto=format&fit=crop&w=1350&q=80');
# ...
